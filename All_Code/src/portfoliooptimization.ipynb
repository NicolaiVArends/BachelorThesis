# %%
import yfinance as yf
import pandas as pd
import datetime as dt
import numpy as np

# Get a list of S&P 500 tickers
sp500 = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]
tickers = sp500['Symbol'].tolist()

# Set the start and end dates for the historical data
start_date = dt.datetime.now() - dt.timedelta(days=3650*2) # last ten years
end_date = dt.datetime.now()

# Define a function to get the historical monthly data and simulate ESG scores for a given ticker
def get_data_and_esg(ticker):
    # Download the historical data from Yahoo Finance
    data = yf.download(ticker, start=start_date, end=end_date, interval='1mo')
    # Remove any rows with missing values
    data.dropna(inplace=True)
    # Define the ESG score array
    esg = np.random.randint(0, 101, size=len(data)//6) # simulate bi-annual updates
    esg = np.repeat(esg, 6) # repeat the same score for each month in the bi-annual period
    esg = np.append(esg, np.repeat(esg[-1], len(data) % 6)) # repeat the last score for any remaining months
    # Return a dataframe with the 'Close' column and the simulated ESG scores
    return pd.DataFrame({'Close': data['Close'], 'ESG': esg}, index=data.index)

# Loop through all tickers and download the data and simulate ESG scores
all_data = pd.DataFrame()
for ticker in tickers:
    print('Downloading data and simulating ESG for', ticker)
    try:
        data = get_data_and_esg(ticker)
        data.columns = pd.MultiIndex.from_product([[ticker], data.columns])
        all_data = pd.concat([all_data, data], axis=1)
    except:
        pass

# Save the data to a CSV file
all_data
# Out:
# Downloading data and simulating ESG for MMM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AOS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ABT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ABBV
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ABBV: Exception('Lost data during merge despite all attempts to align data (see above)')
# Downloading data and simulating ESG for ACN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ATVI
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ADM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ADBE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ADP
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AAP
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AES
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AFL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for A
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for APD
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AKAM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ALK
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ALB
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ARE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ALGN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ALLE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for LNT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ALL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for GOOGL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for GOOG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MO
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AMZN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AMCR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AMD
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AEE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AAL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AEP
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AXP
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AIG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AMT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AWK
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AMP
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ABC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AME
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AMGN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for APH
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ADI
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ANSS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AON
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for APA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AAPL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AMAT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for APTV
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ACGL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ANET
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AJG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AIZ
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for T
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ATO
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ADSK
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AZO
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AVB
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AVY
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for BKR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for BALL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for BAC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for BBWI
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for BAX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for BDX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for WRB
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for BRK.B
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BRK.B: No timezone found, symbol may be delisted
# Downloading data and simulating ESG for BBY
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for BIO
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TECH
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for BIIB
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for BLK
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for BK
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for BA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for BKNG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for BWA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for BXP
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for BSX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for BMY
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for AVGO
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for BR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for BRO
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for BF.B
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BF.B: No data found for this date range, symbol may be delisted
# Downloading data and simulating ESG for BG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CHRW
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CDNS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CZR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CPT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CPB
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for COF
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CAH
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for KMX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CCL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CARR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CTLT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CAT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CBOE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CBRE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CDW
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CNC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CNP
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CDAY
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CF
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CRL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for SCHW
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CHTR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CVX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CMG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CB
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CHD
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CI
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CINF
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CTAS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CSCO
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for C
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CFG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CLX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CME
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CMS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for KO
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CTSH
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CMCSA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CMA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CAG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for COP
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ED
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for STZ
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CEG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for COO
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CPRT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for GLW
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CTVA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CSGP
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for COST
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CTRA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CCI
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CSX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CMI
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CVS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DHI
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DHR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DRI
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DVA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DAL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for XRAY
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DVN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DXCM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for FANG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DLR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DFS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DISH
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DIS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DLTR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for D
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DPZ
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DOV
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DOW
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DTE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DUK
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DD
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DXC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for EMN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ETN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for EBAY
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ECL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for EIX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for EW
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for EA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ELV
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for LLY
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for EMR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ENPH
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ETR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for EOG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for EPAM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for EQT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for EFX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for EQIX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for EQR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ESS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for EL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ETSY
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for RE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for EVRG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ES
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for EXC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for EXPE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for EXPD
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for EXR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for XOM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for FFIV
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for FDS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for FICO
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for FAST
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for FRT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for FDX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for FITB
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for FRC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for FSLR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for FE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for FIS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for FISV
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for FLT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for FMC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for F
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for FTNT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for FTV
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for FOXA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for FOX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for BEN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for FCX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for GRMN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for IT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for GEHC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for GEN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for GNRC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for GD
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for GE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for GIS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for GM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for GPC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for GILD
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for GL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for GPN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for GS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for HAL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for HIG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for HAS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for HCA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PEAK
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for HSIC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for HSY
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for HES
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for HPE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for HLT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for HOLX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for HD
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for HON
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for HRL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for HST
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for HWM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for HPQ
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for HUM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for HBAN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for HII
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for IBM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for IEX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for IDXX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ITW
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ILMN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for INCY
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for IR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PODD
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for INTC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ICE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for IFF
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for IP
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for IPG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for INTU
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ISRG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for IVZ
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for INVH
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for IQV
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for IRM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for JBHT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for JKHY
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for J
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for JNJ
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for JCI
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for JPM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for JNPR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for K
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for KDP
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for KEY
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for KEYS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for KMB
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for KIM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for KMI
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for KLAC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for KHC
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - KHC: Exception('Lost data during merge despite all attempts to align data (see above)')
# Downloading data and simulating ESG for KR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for LHX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for LH
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for LRCX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for LW
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for LVS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for LDOS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for LEN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for LNC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for LIN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for LYV
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for LKQ
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for LMT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for L
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for LOW
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for LYB
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MTB
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MRO
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MPC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MKTX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MAR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MMC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MLM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MAS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MTCH
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MKC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MCD
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MCK
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MDT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MRK
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for META
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MET
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MTD
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MGM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MCHP
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MU
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MSFT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MAA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MRNA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MHK
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MOH
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TAP
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MDLZ
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MPWR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MNST
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MCO
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MOS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MSI
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for MSCI
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for NDAQ
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for NTAP
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for NFLX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for NWL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for NEM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for NWSA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for NWS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for NEE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for NKE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for NI
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for NDSN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for NSC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for NTRS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for NOC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for NCLH
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for NRG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for NUE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for NVDA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for NVR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for NXPI
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ORLY
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for OXY
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ODFL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for OMC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ON
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for OKE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ORCL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for OGN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for OTIS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PCAR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PKG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PARA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PH
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PAYX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PAYC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PYPL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PNR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PEP
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PKI
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PFE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PCG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PSX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PNW
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PXD
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PNC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for POOL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PPG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PPL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PFG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PGR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PLD
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PRU
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PEG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PTC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PSA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PHM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for QRVO
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for PWR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for QCOM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for DGX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for RL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for RJF
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for RTX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for O
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for REG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for REGN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for RF
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for RSG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for RMD
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for RHI
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ROK
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ROL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ROP
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ROST
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for RCL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for SPGI
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for CRM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for SBAC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for SLB
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for STX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for SEE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for SRE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for NOW
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for SHW
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for SPG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for SWKS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for SJM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for SNA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for SEDG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for SO
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for LUV
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for SWK
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for SBUX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for STT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for STLD
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for STE
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for SYK
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for SYF
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for SNPS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for SYY
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TMUS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TROW
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TTWO
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TPR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TRGP
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TGT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TEL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TDY
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TFX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TER
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TSLA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TXN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TXT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TMO
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TJX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TSCO
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TDG
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TRV
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TRMB
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TFC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TYL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for TSN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for USB
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for UDR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ULTA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for UNP
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for UAL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for UPS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for URI
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for UNH
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for UHS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for VLO
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for VTR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for VRSN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for VRSK
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for VZ
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for VRTX
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for VFC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for VTRS
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for VICI
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for V
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for VMC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for WAB
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for WBA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for WMT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for WBD
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for WM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for WAT
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for WEC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for WFC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for WELL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for WST
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for WDC
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for WRK
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for WY
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for WHR
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for WMB
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for WTW
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for GWW
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for WYNN
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for XEL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for XYL
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for YUM
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ZBRA
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ZBH
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ZION
# [*********************100%***********************]  1 of 1 completed
# Downloading data and simulating ESG for ZTS
# [*********************100%***********************]  1 of 1 completed

# %%
#We create a rolling variance, mean and covariance, to measue stock volatility, and update our portfolio every 6 months, based on a weighted esg score of 80

#size of portfolio 100 stocks

#Weighted average combination of esg score = 80

# Other solution we cut off companies with esg score below 80

# %%
import pandas as pd
import numpy as np
import cvxpy as cp

# Load the data
data = all_data
start_date = dt.datetime.now() - dt.timedelta(days=3650*2) # last ten years
end_date = dt.datetime.now()

# Define the input parameters

esg_threshold = 79
num_months = (pd.to_datetime(end_date) - pd.to_datetime(start_date)).days // 30
print(data.loc[end_date])
selected_data = data.loc[start_date:end_date, data.loc[end_date].astype(int) > esg_threshold].astype(float)
returns = selected_data.pct_change().dropna()

# Define the objective function to be maximized, which is the negative Sharpe ratio
n = len(selected_data.columns)
w = cp.Variable(n)
ret = returns.mean() @ w
risk = cp.quad_form(w, returns.cov())
lambda_ = cp.Parameter(nonneg=True)
problem = cp.Problem(cp.Maximize(ret - lambda_ * risk), [cp.sum(w) == 1, w >= 0])

# Compute the efficient frontier for various values of lambda
MIN_LAMBDA = 0
MAX_LAMBDA = 5
NUM_POINTS = 100
lambdas = np.linspace(MIN_LAMBDA, MAX_LAMBDA, NUM_POINTS)
returns_list = []
risk_list = []
for l in lambdas:
    lambda_.value = l
    problem.solve()
    returns_list.append(ret.value)
    risk_list.append(cp.sqrt(risk).value)

# Compute the optimal portfolio for the given value of lambda
lambda_.value = 1
problem.solve()
optimal_weights = w.value

# Print the results
print("Optimal weights:", optimal_weights)
print("Expected return:", ret.value)
print("Volatility:", cp.sqrt(risk).value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Tor Osted\OneDrive\Dokumenter\GitHub\BachelorThesis\All_Code\src\portfoliooptimization.ipynb Cell 3 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Tor%20Osted/OneDrive/Dokumenter/GitHub/BachelorThesis/All_Code/src/portfoliooptimization.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> import cvxpy as cp
#       <a href='vscode-notebook-cell:/c%3A/Users/Tor%20Osted/OneDrive/Dokumenter/GitHub/BachelorThesis/All_Code/src/portfoliooptimization.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> # Load the data
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tor%20Osted/OneDrive/Dokumenter/GitHub/BachelorThesis/All_Code/src/portfoliooptimization.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> data = pd.read_csv('sp500_monthly_data_and_esg.csv', index_col='Date')
#       <a href='vscode-notebook-cell:/c%3A/Users/Tor%20Osted/OneDrive/Dokumenter/GitHub/BachelorThesis/All_Code/src/portfoliooptimization.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> start_date = dt.datetime.now() - dt.timedelta(days=3650*2) # last ten years
#       <a href='vscode-notebook-cell:/c%3A/Users/Tor%20Osted/OneDrive/Dokumenter/GitHub/BachelorThesis/All_Code/src/portfoliooptimization.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> end_date = dt.datetime.now()
#
# File c:\Users\Tor Osted\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\Tor Osted\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Tor Osted\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File c:\Users\Tor Osted\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1254, in TextFileReader.read(self, nrows)
#    1252 nrows = validate_integer("nrows", nrows)
#    1253 try:
# -> 1254     index, columns, col_dict = self._engine.read(nrows)
#    1255 except Exception:
#    1256     self.close()
#
# File c:\Users\Tor Osted\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:311, in CParserWrapper.read(self, nrows)
#     308     data = {k: v for k, (i, v) in zip(names, data_tups)}
#     310     names, date_data = self._do_date_conversions(names, data)
# --> 311     index, names = self._make_index(date_data, alldata, names)
#     313 # maybe create a mi on the columns
#     314 conv_names = self._maybe_make_multi_index_columns(names, self.col_names)
#
# File c:\Users\Tor Osted\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\base_parser.py:389, in ParserBase._make_index(self, data, alldata, columns, indexnamerow)
#     386     index = None
#     388 elif not self._has_complex_date_col:
# --> 389     index = self._get_simple_index(alldata, columns)
#     390     index = self._agg_index(index)
#     391 elif self._has_complex_date_col:
#
# File c:\Users\Tor Osted\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\base_parser.py:421, in ParserBase._get_simple_index(self, data, columns)
#     419 index = []
#     420 for idx in self.index_col:
# --> 421     i = ix(idx)
#     422     to_remove.append(i)
#     423     index.append(data[i])
#
# File c:\Users\Tor Osted\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\base_parser.py:416, in ParserBase._get_simple_index.<locals>.ix(col)
#     414 if not isinstance(col, str):
#     415     return col
# --> 416 raise ValueError(f"Index {col} invalid")
#
# ValueError: Index Date invalid
