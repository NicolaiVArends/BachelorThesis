# %%
import pandas as pd
from src.data import *
from src.portfolio import *
from src.efficient_frontier import *
from src.plot import *
import yfinance as yf
from scipy.optimize import Bounds, LinearConstraint

# %%
df = pd.read_excel(r"C:\Users\Tor Osted\OneDrive\Dokumenter\GitHub\BachelorThesis\data\ESG_DATA_S&P500.xlsx")
weights = np.array([0,0,1])

# %%
esg_score_weight(df,weights,1221)
# Out:
#              Isin CurrencyCode                        company_name  \
# 2    US0304201033          USD  American Water Works Company, Inc.
# 77   US1258961002          USD              CMS Energy Corporation
# 81   US17275R1023          USD                 Cisco Systems, Inc.
# 129  US2091151041          USD           Consolidated Edison, Inc.
# 137  US2810201077          USD                Edison International
# 228  US4581401001          USD                   Intel Corporation
# 277  US5949181045          USD               Microsoft Corporation
# 327  US7234841010          USD   Pinnacle West Capital Corporation
# 333  US7433151039          USD         The Progressive Corporation
# 427  US3848021040          USD                 W.W. Grainger, Inc.
# 433  US92939U1060          USD              WEC Energy Group, Inc.
#
#     environment_grade environment_level  environment_score  esg_id  \
# 2                  AA         Excellent                680     418
# 77                 BB            Medium                338    1711
# 81                  B            Medium                235   73680
# 129                AA         Excellent                600    1855
# 137                 A              High                511    2361
# 228                BB            Medium                395    3799
# 277                AA         Excellent                805    4720
# 327                 A              High                534    5651
# 333                BB            Medium                380    5795
# 427                 B            Medium                275    7631
# 433                 A              High                596    7672
#
#     exchange_symbol governance_grade governance_level  governance_score  \
# 2              NYSE               BB           Medium               300
# 77             NYSE                C              Low                75
# 81           NASDAQ                B           Medium               230
# 129            NYSE               BB           Medium               320
# 137            NYSE               BB           Medium               300
# 228             NaN                A             High               565
# 277          NASDAQ               BB           Medium               390
# 327            NYSE               BB           Medium               300
# 333            NYSE                B           Medium               263
# 427            NYSE                B           Medium               215
# 433            NYSE               BB           Medium               320
#
#      last_processing_date social_grade social_level  social_score  \
# 2                20230221          BBB         High           407
# 77               20230221          BBB         High           434
# 81               20230301            A         High           540
# 129              20230221          BBB         High           421
# 137              20230222          BBB         High           418
# 228              20230222          BBB         High           426
# 277              20230222            A         High           504
# 327              20230222          BBB         High           481
# 333              20230222          BBB         High           418
# 427              20230223          BBB         High           418
# 433              20230223          BBB         High           451
#
#     stock_symbol  total total_grade total_level  weighted_score
# 2            AWK   1387           A        High            1221
# 77           CMS    847          BB      Medium            1302
# 81          CSCO   1005         BBB        High            1620
# 129           ED   1341           A        High            1263
# 137          EIX   1229           A        High            1254
# 228         INTC   1386           A        High            1278
# 277         MSFT   1699           A        High            1512
# 327          PNW   1315           A        High            1443
# 333          PGR   1061         BBB        High            1254
# 427          GWW    908         BBB        High            1254
# 433          WEC   1367           A        High            1353
