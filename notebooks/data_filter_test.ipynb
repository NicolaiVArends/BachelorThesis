# %%
from src import data
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel(r"C:\Users\Tor Osted\OneDrive\Dokumenter\GitHub\BachelorThesis\All_Code\test_data\test_esg_sp500_after_test.xlsx").iloc[:,1:].reset_index(drop=True)

# %%
df2 = data.esg_score_weight(pd.read_excel(r"C:\Users\Tor Osted\OneDrive\Dokumenter\GitHub\BachelorThesis\All_Code\test_data\test_esg_sp500_data.xlsx"),np.array([1/3,1/3,1/3]),1150).iloc[:,1:].reset_index(drop=True) #vægtfunktionen skal fikses

# %%
df1.equals(df2)
# Out:
# False

# %%
df1 = data.esg_score_weight(pd.read_excel(r"C:\Users\Tor Osted\OneDrive\Dokumenter\GitHub\BachelorThesis\All_Code\test_data\test_esg_sp500_data.xlsx"),np.array([1/3,1/3,1/3]),1150)
df2 = pd.read_excel(r"C:\Users\Tor Osted\OneDrive\Dokumenter\GitHub\BachelorThesis\All_Code\test_data\test_esg_sp500_after_test.xlsx").sort_index().sort_index(axis=1)

# %%
df1 = data.esg_score_weight(pd.read_excel(r"C:\Users\Tor Osted\OneDrive\Dokumenter\GitHub\BachelorThesis\All_Code\test_data\test_esg_sp500_data.xlsx"),np.array([1/3,1/3,1/3]),1150).sort_index().sort_index(axis=1).reset_index(drop=True)

# %%
df1
# Out:
#   CurrencyCode          Isin  Unnamed: 0                        company_name  \
# 0          USD  US0268747849           0  American International Group, Inc.
# 1          USD  US0304201033           2  American Water Works Company, Inc.
# 2          USD  US03073E1055           4       AmerisourceBergen Corporation
# 3          USD  US0311001004           5                        AMETEK, Inc.
# 4          USD  US0311621009           6                          Amgen Inc.
# 5          USD  US0320951017           7                Amphenol Corporation
# 6          USD  US0326541051           8                Analog Devices, Inc.
# 7          USD  US03662Q1058           9                         ANSYS, Inc.
#
#   environment_grade environment_level  environment_score  esg_id  \
# 0                 A              High                538     390
# 1                AA         Excellent                680     418
# 2                 A              High                550     426
# ...

# %%
df2 = df2.reset_index(drop=True)
# Out:
#   CurrencyCode          Isin  Unnamed: 0                        company_name  \
# 0          USD  US0268747849           0  American International Group, Inc.
# 1          USD  US0304201033           1  American Water Works Company, Inc.
# 2          USD  US03073E1055           2       AmerisourceBergen Corporation
# 3          USD  US0311001004           3                        AMETEK, Inc.
# 4          USD  US0311621009           4                          Amgen Inc.
# 5          USD  US0320951017           5                Amphenol Corporation
# 6          USD  US0326541051           6                Analog Devices, Inc.
# 7          USD  US03662Q1058           7                         ANSYS, Inc.
#
#   environment_grade environment_level  environment_score  esg_id  \
# 0                 A              High                538     390
# 1                AA         Excellent                680     418
# 2                 A              High                550     426
# ...

# %%
df2.equals(df1)
# Out:
# False
